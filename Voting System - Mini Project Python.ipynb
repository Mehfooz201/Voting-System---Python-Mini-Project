# %% [markdown]
# # Voting System - Mini Project

# %%
candidate1 = input("Enter first candidate name : ")
candidate2 = input("Enter second candidate name : ")

cand1_votes = 0
cand2_votes = 0

voter_id = [101, 102, 103, 104, 105, 106, 107]
no_of_voters = len(voter_id)

print("Number of Voters : ", no_of_voters)
voted=[]

while True:
    if voter_id==[]:
        print("Voting is Over !!!")
        
        if cand1_votes>cand2_votes:
            print(f"{candidate1} won the Elections with the {cand1_votes} votes .")
        elif cand2_votes>cand1_votes:
            print(f"{candidate2} won the Elections with the {cand2_votes} votes.")
        break
        
    else:
        voter = int(input("Enter your id : "))
        
        if voter in voted:
            print("You already voted !")
            
        else:
            if voter in voter_id:
                print(f"1.{candidate1}\n2.{candidate2}")
                choice = int(input("Enter your choice : "))
                
                if choice==1:
                    cand1_votes+=1
                    print(f"You voted {candidate1}")
                    
                elif choice==2:
                    cand2_votes+=1
                    print(f"You voted {candidate2}")
                    
                voter_id.remove(voter)
                voted.append(voter)
            else:
                print("You are not allowed to vote !")
# Out:
# Enter first candidate name : Mehfooz
# Enter second candidate name : Sadia
# Number of Voters :  7
# Enter your id : 101
# 1.Mehfooz
# 2.Sadia
# Enter your choice : 1
# You voted Mehfooz
# Enter your id : 102
# 1.Mehfooz
# 2.Sadia
# Enter your choice : 2
# You voted Sadia
# Enter your id : 105
# 1.Mehfooz
# 2.Sadia
# Enter your choice : 1
# You voted Mehfooz
# Enter your id : 106
# 1.Mehfooz
# 2.Sadia
# Enter your choice : 1
# You voted Mehfooz
# Enter your id : 103
# 1.Mehfooz
# 2.Sadia
# Enter your choice : 2
# You voted Sadia
# Enter your id : 104
# 1.Mehfooz
# 2.Sadia
# Enter your choice : 2
# You voted Sadia
# Enter your id : 107
# 1.Mehfooz
# 2.Sadia
# Enter your choice : 1
# You voted Mehfooz
# Voting is Over !!!
# Mehfooz won the Elections with the 4 votes .

# %%
candidate1 = input("Enter first candidate name : ")
candidate2 = input("Enter second candidate name : ")

cand1_votes = 0
cand2_votes = 0

voter_id = [101, 102, 103, 104, 105, 106, 107]
no_of_voters = len(voter_id)

print("Number of Voters : ", no_of_voters)
voted=[]

while True:
    if voter_id==[]:
        print("Voting is Over !!!")
        
        if cand1_votes>cand2_votes:
            print(f"{candidate1} won the Elections with the {cand1_votes} votes .")
        elif cand2_votes>cand1_votes:
            print(f"{candidate2} won the Elections with the {cand2_votes} votes.")
        break
        
    else:
        voter = int(input("Enter your id : "))
        
        if voter in voted:
            print("You already voted !")
            
        else:
            if voter in voter_id:
                print(f"1.{candidate1}\n2.{candidate2}")
                choice = int(input("Enter your choice : "))
                
                if choice==1:
                    cand1_votes+=1
                    print(f"You voted {candidate1}")
                    
                elif choice==2:
                    cand2_votes+=1
                    print(f"You voted {candidate2}")
                    
                voter_id.remove(voter)
                voted.append(voter)
            else:
                print("You are not allowed to vote !")
# Out:
# Enter first candidate name : Mehfooz
# Enter second candidate name : Wajid
# Number of Voters :  7
# Enter your id : 108
# You are not allowed to vote !
# Enter your id : 109
# You are not allowed to vote !
# Enter your id : 104
# 1.Mehfooz
# 2.Wajid
# Enter your choice : 1
# You voted Mehfooz
# Enter your id : 104
# You already voted !
# Enter your id : 1
# You are not allowed to vote !
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_9620/769783676.py in <module>
#      22
#      23     else:
# ---> 24         voter = int(input("Enter your id : "))
#      25
#      26         if voter in voted:
#
# ~\anaconda3\lib\site-packages\ipykernel\kernelbase.py in raw_input(self, prompt)
#    1004                 "raw_input was called, but this frontend does not support input requests."
#    1005             )
# -> 1006         return self._input_request(
#    1007             str(prompt),
#    1008             self._parent_ident["shell"],
#
# ~\anaconda3\lib\site-packages\ipykernel\kernelbase.py in _input_request(self, prompt, ident, parent, password)
#    1049             except KeyboardInterrupt:
#    1050                 # re-raise KeyboardInterrupt, to truncate traceback
# -> 1051                 raise KeyboardInterrupt("Interrupted by user") from None
#    1052             except Exception:
#    1053                 self.log.warning("Invalid Message:", exc_info=True)
#
# KeyboardInterrupt: Interrupted by user

# %%
candidate1 = input("Enter first candidate name : ")
candidate2 = input("Enter second candidate name : ")

cand1_votes = 0
cand2_votes = 0

voter_id = [101, 102, 103, 104, 105, 106, 107]
no_of_voters = len(voter_id)

print("Number of Voters : ", no_of_voters)
voted=[]

while True:
    if voter_id!=[]:
        print("Voting is Over !!!")
        
        if cand1_votes>cand2_votes:
            print(f"{candidate1} won the Elections with the {cand1_votes} votes .")
        elif cand2_votes>cand1_votes:
            print(f"{candidate2} won the Elections with the {cand2_votes} votes.")
        break
        
    else:
        voter = int(input("Enter your id : "))
        
        if voter in voted:
            print("You already voted !")
            
        else:
            if voter in voter_id:
                print(f"1.{candidate1}\n2.{candidate2}")
                choice = int(input("Enter your choice : "))
                
                if choice==1:
                    cand1_votes+=1
                    print(f"You voted {candidate1}")
                    
                elif choice==2:
                    cand2_votes+=1
                    print(f"You voted {candidate2}")
                    
                voter_id.remove(voter)
                voted.append(voter)
            else:
                print("You are not allowed to vote !")
# Out:
# Enter first candidate name : mehfooz
# Enter second candidate name : sadia
# Number of Voters :  7
# Voting is Over !!!
